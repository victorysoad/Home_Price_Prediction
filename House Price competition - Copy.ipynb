# %%
#! pip install pycaret

# %%
#pip install --upgrade jinja2

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 90)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')

from sklearn.neighbors import KNeighborsRegressor
import scipy.stats
from sklearn.preprocessing import StandardScaler

from pycaret.regression import setup, compare_models

from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

from sklearn.model_selection import KFold, cross_val_score

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
train0 = pd.read_csv('Train.csv')
test0 = pd.read_csv('Test.csv') 
sample_submission = pd.read_csv('sample_submission.csv')

# %%
train0
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
sample_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %% [markdown]
# ## Cleaning

# %%
train0.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
test0.isna().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# # Combine train and test sets

# %%
target = train0['SalePrice']
test_ids = test0['Id']

train1 = train0.drop(['Id','SalePrice'], axis = 1)
test1 = test0.drop(['Id'], axis = 1)

data1 = pd.concat([train1,test1], axis=0).reset_index(drop=True)
data1
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %% [markdown]
# # Ensure Proper Data Types

# %%
data2 = data1.copy()

# %%
# categoric , but was encoded as numeric(check description)
data2['MSSubClass'] = data2['MSSubClass'].astype(str)

# %% [markdown]
# # Fill categorical missing values

# %%
# Impute using a constant value

for column in ['Alley','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1', 'BsmtFinType2',
              'FireplaceQu','GarageType', 'GarageFinish', 'GarageQual', 'GarageCond','PoolQC', 
              'Fence','MiscFeature']:
    data2[column] = data2[column].fillna('None')


# Impute using column mode
for column in ['MSZoning','Utilities','Exterior1st', 'Exterior2nd','MasVnrType','Electrical','KitchenQual', 
              'Functional', 'SaleType']:
    data2[column] = data2[column].fillna(data2[column].mode()[0])

# %%
data2.select_dtypes('object').loc[:, data2.isna().sum()>0].columns
# Out:
# Index([], dtype='object')

# %%
data3 = data2.copy()

# %% [markdown]
# # Numeric missing values

# %%
def knn_impute(df, na_target):
    df = df.copy()
    
    numeric_df = df.select_dtypes(np.number)
    non_na_columns = numeric_df.loc[:,numeric_df.isna().sum()==0].columns
    
    y_train = numeric_df.loc[numeric_df[na_target].isna() == False, na_target]
    X_train = numeric_df.loc[numeric_df[na_target].isna() == False, non_na_columns]
    X_test = numeric_df.loc[numeric_df[na_target].isna() == True, non_na_columns]
    
    knn = KNeighborsRegressor()
    knn.fit(X_train, y_train)
    
    y_pred = knn.predict(X_test)
    
    df.loc[df[na_target].isna() == True, na_target] = y_pred
    
    return df

# %%
data3.columns[data3.isna().sum()>0]
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
#        'GarageCars', 'GarageArea'],
#       dtype='object')

# %%
for column in ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
       'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt',
       'GarageCars', 'GarageArea']:
    data3 = knn_impute(data3, column)

# %%
data3.isna().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# Alley            0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
data4 = data3.copy()

# %% [markdown]
# # Feature engineering

# %%
data4
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 2914        160       RM         21.0     1936   Pave  None      Reg
# 2915        160       RM         21.0     1894   Pave  None      Reg
# 2916         20       RL        160.0    20000   Pave  None      Reg
# 2917         85       RL         62.0    10441   Pave  None      Reg
# 2918         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data4['SqFtPerRoom'] = data4['GrLivArea'] / (data4['TotRmsAbvGrd']+ data4['FullBath'] +data4["HalfBath"] +data4['KitchenAbvGr'])
data4['Total_Home_Quality'] = data4 ['OverallQual'] + data4 ['OverallCond']
data4['Total_Bathrooms'] = (data4['FullBath'] + (0.5* data4['HalfBath']) +data4['BsmtFullBath']+(0.5 * data4['BsmtHalfBath']))
data4['HighQualSF'] = data4['1stFlrSF'] + data4['2ndFlrSF']

# %%
data4
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave  None      Reg
# 1            20       RL         80.0     9600   Pave  None      Reg
# 2            60       RL         68.0    11250   Pave  None      IR1
# 3            70       RL         60.0     9550   Pave  None      IR1
# 4            60       RL         84.0    14260   Pave  None      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 2914        160       RM         21.0     1936   Pave  None      Reg
# 2915        160       RM         21.0     1894   Pave  None      Reg
# 2916         20       RL        160.0    20000   Pave  None      Reg
# 2917         85       RL         62.0    10441   Pave  None      Reg
# 2918         60       RL         74.0     9627   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
data5 = data4.copy()

# %% [markdown]
# # Feature transformations

# %% [markdown]
# ### Log transform for skewed features

# %%
skew_df = pd.DataFrame(data5.select_dtypes(np.number).columns, columns=['Feature']) 
skew_df['Skew']= skew_df['Feature'].apply(lambda feature: scipy.stats.skew(data5[feature]))
skew_df['Absolute Skew'] = skew_df['Skew'].apply(abs)
skew_df['Skewed'] = skew_df['Absolute Skew']. apply(lambda x: True if x>=0.5 else False)
skew_df
# Out:
#                Feature       Skew  Absolute Skew  Skewed
# 0          LotFrontage   1.340751       1.340751    True
# 1              LotArea  12.822431      12.822431    True
# 2          OverallQual   0.197110       0.197110   False
# 3          OverallCond   0.570312       0.570312    True
# 4            YearBuilt  -0.599806       0.599806    True
# 5         YearRemodAdd  -0.451020       0.451020   False
# 6           MasVnrArea   2.603682       2.603682    True
# 7           BsmtFinSF1   1.425516       1.425516    True
# 8           BsmtFinSF2   4.146111       4.146111    True
# 9            BsmtUnfSF   0.919322       0.919322    True
# 10         TotalBsmtSF   1.162806       1.162806    True
# 11            1stFlrSF   1.469604       1.469604    True
# 12            2ndFlrSF   0.861675       0.861675    True
# 13        LowQualFinSF  12.088761      12.088761    True
# 14           GrLivArea   1.269358       1.269358    True
# ...

# %%
data5[skew_df.query('Skewed == True')['Feature'].values].describe()
#have 0 for min a lot, use log1p
# Out:
#        LotFrontage        LotArea  OverallCond    YearBuilt   MasVnrArea  \
# count  2919.000000    2919.000000  2919.000000  2919.000000  2919.000000
# mean     70.154916   10168.114080     5.564577  1971.312778   102.189654
# std      22.697641    7886.996359     1.113131    30.291442   178.934095
# min      21.000000    1300.000000     1.000000  1872.000000     0.000000
# 25%      60.000000    7478.000000     5.000000  1953.500000     0.000000
# 50%      70.000000    9453.000000     5.000000  1973.000000     0.000000
# 75%      80.100000   11570.000000     6.000000  2001.000000   164.000000
# max     313.000000  215245.000000     9.000000  2010.000000  1600.000000
#
#         BsmtFinSF1   BsmtFinSF2    BsmtUnfSF  TotalBsmtSF     1stFlrSF  \
# count  2919.000000  2919.000000  2919.000000  2919.000000  2919.000000
# mean    441.332580    49.576841   560.797670  1051.679822  1159.581706
# std     455.559081   169.176867   439.470508   440.722380   392.362079
# ...

# %%
for column in skew_df.query('Skewed == True')['Feature'].values:
    data5[column] = np.log1p(data5[column])

# %% [markdown]
# ### Cosine transform for weateher

# %%
#months transformation

data5['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %%
#cold for winter, hot for summer 
# - cos(0.5236x)
-np.cos(0.5236*data5['MoSold'])
# Out:
# 0      -0.499998
# 1       0.866028
# 2      -0.000011
# 3      -0.499998
# 4      -1.000000
#           ...
# 2914    1.000000
# 2915    0.500004
# 2916   -0.000011
# 2917    0.866021
# 2918   -0.866032
# Name: MoSold, Length: 2919, dtype: float64

# %%
data5['MoSold'] = -np.cos(0.5236*data5['MoSold'])

# %%
data6 = data5.copy()

# %% [markdown]
# ## Encode categorical variables

# %%
data6 = pd.get_dummies(data6)

# %%
data7 = data6.copy()

# %% [markdown]
# ## Scaling

# %%
scaler = StandardScaler()
scaler.fit(data7)

data7 = pd.DataFrame(scaler.transform(data7), index = data7.index, columns = data7.columns)

# %%
data7
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.064176 -0.103719     0.646183    -0.435439   1.040634
# 1        0.536077  0.146544    -0.063185     1.906370   0.161526
# 2        0.066112  0.457629     0.646183    -0.435439   0.975922
# 3       -0.295084  0.136301     0.646183    -0.435439  -1.869638
# 4        0.677357  0.922662     1.355551    -0.435439   0.943542
# ...           ...       ...          ...          ...        ...
# 2914    -3.284214 -2.993401    -1.481920     1.226101  -0.035461
# 2915    -3.284214 -3.036401    -1.481920    -0.435439  -0.035461
# 2916     2.549545  1.586172    -0.772552     1.226101  -0.365110
# 2917    -0.200527  0.311255    -0.772552    -0.435439   0.683917
# 2918     0.310504  0.152052     0.646183    -0.435439   0.716427
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         0.896833    1.210174    0.783229   -0.363076  -0.326949
# ...

# %%
data8 = data7.copy()

# %% [markdown]
# # Target transformation

# %%
plt.figure( figsize = (20,10))

plt.subplot(1,2,1)
sns.distplot(target, fit = scipy.stats.norm)
plt.title('Without Log Transform')

plt.subplot(1,2,2)
sns.distplot(np.log(target), fit = scipy.stats.norm)
plt.xlabel('Log SalePrice')
plt.title('With Log Transform')

plt.show()

# %%
log_target = np.log(target)

# %% [markdown]
# # Split Data

# %%
train_final = data8.loc[:train0.index.max(),:].copy()
test_final = data8.loc[train0.index.max()+1:,:].reset_index(drop = True).copy()

# %%
train_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0       -0.064176 -0.103719     0.646183    -0.435439   1.040634
# 1        0.536077  0.146544    -0.063185     1.906370   0.161526
# 2        0.066112  0.457629     0.646183    -0.435439   0.975922
# 3       -0.295084  0.136301     0.646183    -0.435439  -1.869638
# 4        0.677357  0.922662     1.355551    -0.435439   0.943542
# ...           ...       ...          ...          ...        ...
# 1455    -0.200527 -0.231508    -0.063185    -0.435439   0.911146
# 1456     0.711638  0.767440    -0.063185     0.454875   0.227056
# 1457    -0.020100  0.029092     0.646183     2.514892  -0.996100
# 1458     0.066112  0.170303    -0.772552     0.454875  -0.696444
# 1459     0.349325  0.214215    -0.772552     0.454875  -0.200076
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0         0.896833    1.210174    0.783229   -0.363076  -0.326949
# ...

# %%
test_final
# Out:
#       LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        0.536077  0.521437    -0.772552     0.454875  -0.332070
# 1        0.572040  0.923625    -0.063185     0.454875  -0.431241
# 2        0.310504  0.862607    -0.772552    -0.435439   0.846305
# 3        0.462798  0.222291    -0.063185     0.454875   0.878733
# 4       -1.252596 -1.130892     1.355551    -0.435439   0.683917
# ...           ...       ...          ...          ...        ...
# 1454    -3.284214 -2.993401    -1.481920     1.226101  -0.035461
# 1455    -3.284214 -3.036401    -1.481920    -0.435439  -0.035461
# 1456     2.549545  1.586172    -0.772552     1.226101  -0.365110
# 1457    -0.200527  0.311255    -0.772552    -0.435439   0.683917
# 1458     0.310504  0.152052     0.646183    -0.435439   0.716427
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0        -1.113625   -0.804554    0.645518    2.285649  -0.013563
# ...

# %% [markdown]
# # Model selection

# %%
_ = setup(data=pd.concat([train_final, log_target], axis = 1), target = 'SalePrice')
# Out:
# <style type="text/css">
# #T_4c214_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4c214">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c214_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4c214_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c214_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c214_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4c214_row0_col1" class="data row0 col1" >8846</td>
#     </tr>
#     <tr>
#       <th id="T_4c214_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4c214_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4c214_row1_col1" class="data row1 col1" >SalePrice</td>
#     </tr>
#     <tr>
#       <th id="T_4c214_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#compare_models()

# %%
#Orthogonal Matching Pursuit
#Bayesian Ridge
#Ridge Regression
#Gradient Boosting Regressor
#Light Gradient Boosting Machine
#Random Forest Regressor
#Extreme Gradient Boosting

# %%
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import OrthogonalMatchingPursuit
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from lightgbm import LGBMRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# %% [markdown]
# # Baseline Model (BayesianRidge)

# %%
baseline_model = BayesianRidge(verbose = 0)

# %%
baseline_model.fit (train_final, log_target)
# Out:
# BayesianRidge(verbose=0)

# %% [markdown]
# # Evaluete

# %%
kf = KFold(n_splits = 10)

results = cross_val_score(baseline_model, train_final,log_target, scoring = 'neg_mean_squared_error',cv = kf)

# %%
results
# Out:
# array([-0.01408794, -0.01018083, -0.01410679, -0.02400285, -0.02048667,
#        -0.01772634, -0.01454666, -0.00955585, -0.03215727, -0.01587461])

# %%
results.mean()
# Out:
# -0.017272581887423123

# %%
plt.figure(figsize= (16,10))

sns.displot (-results,bins =10, kde = True)

# %%
np.mean(-results)
# Out:
# 0.017272581887423123

# %%
target.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Make Submission

# %%
sample_submission
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %%
test_ids
# Out:
# 0       1461
# 1       1462
# 2       1463
# 3       1464
# 4       1465
#         ...
# 1454    2915
# 1455    2916
# 1456    2917
# 1457    2918
# 1458    2919
# Name: Id, Length: 1459, dtype: int64

# %%
final_predictions = np.exp(baseline_model.predict(test_final))

# %%
submission = pd.concat([test_ids,pd.Series(final_predictions, name = 'SalePrice')], axis = 1)
submission
# Out:
#         Id      SalePrice
# 0     1461  123503.012119
# 1     1462  164193.985582
# 2     1463  183634.649943
# 3     1464  200176.543317
# 4     1465  198353.228213
# ...    ...            ...
# 1454  2915   82555.462948
# 1455  2916   79280.375148
# 1456  2917  169156.537596
# 1457  2918  120093.892264
# 1458  2919  212839.261643
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('./submission.csv', index=False, header = True)

# %% [markdown]
# # LGBM

# %%
lgbm_model = LGBMRegressor(verbose = 0)

# %%
lgbm_model.fit (train_final, log_target)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009922 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# LGBMRegressor(verbose=0)

# %%
kf = KFold(n_splits = 10)

results = cross_val_score(lgbm_model, train_final,log_target, scoring = 'neg_mean_squared_error',cv = kf)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002834 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006785 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# ...

# %%
results.mean()
# Out:
# -0.016979006175759294

# %%
lgbm_predictions = np.exp(lgbm_model.predict(test_final))

# %%
submission = pd.concat([test_ids,pd.Series(lgbm_predictions, name = 'SalePrice')], axis = 1)
submission
# Out:
#         Id      SalePrice
# 0     1461  122334.820543
# 1     1462  151028.443632
# 2     1463  183335.372316
# 3     1464  188081.422730
# 4     1465  191547.080369
# ...    ...            ...
# 1454  2915   75768.492619
# 1455  2916   82754.354353
# 1456  2917  160521.673721
# 1457  2918  112421.701252
# 1458  2919  221924.751357
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('./lgbm_submission.csv', index=False, header = True)

# %% [markdown]
# # Bagging Ansamble

# %% [markdown]
# from sklearn.linear_model import BayesianRidge
# from sklearn.linear_model import OrthogonalMatchingPursuit
# from sklearn.linear_model import Ridge
# from sklearn.ensemble import GradientBoostingRegressor
# from lightgbm import LGBMRegressor
# from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor

# %%
models = {
    'Bayesian Ridge':BayesianRidge(verbose = 0),
    'OrthogonalMatchingPursuit': OrthogonalMatchingPursuit(),
    'Ridge':Ridge(),
    'GradientBoostingRegressor': GradientBoostingRegressor(),
    'LGBMRegressor':LGBMRegressor(),
    'RandomForestRegressor':RandomForestRegressor(),
    'XGBRegressor':XGBRegressor()
    
}

# %%
for name, model in models.items():
    model.fit(train_final, log_target)
    print(name+' trained')
# Out:
# Bayesian Ridge trained
# OrthogonalMatchingPursuit trained
# Ridge trained
# GradientBoostingRegressor trained
# LGBMRegressor trained
# RandomForestRegressor trained
# XGBRegressor trained

# %% [markdown]
# ## Evaluate

# %%
results = {}

kf = KFold(n_splits = 10)

for name, model in models.items():
    result =np.exp(np.sqrt(-cross_val_score(model, train_final,log_target, scoring = 'neg_mean_squared_error',cv = kf)))
    results[name]= result

# %%
results
# Out:
# {'Bayesian Ridge': array([1.12647591, 1.10785636, 1.12698884, 1.16898827, 1.1538688 ,
#         1.14270592, 1.12838629, 1.1032448 , 1.19869609, 1.13673483]),
#  'OrthogonalMatchingPursuit': array([1.12550453, 1.09788011, 1.11981216, 1.17679697, 1.1555808 ,
#         1.16092027, 1.13376685, 1.10647897, 1.19143393, 1.13965602]),
#  'Ridge': array([1.13444613, 1.11198835, 1.12859486, 1.17456205, 1.16031432,
#         1.16639308, 1.13464153, 1.10353113, 1.21332879, 1.13535542]),
#  'GradientBoostingRegressor': array([1.13741305, 1.10855855, 1.12427219, 1.1750619 , 1.16621178,
#         1.11523883, 1.13505141, 1.11429687, 1.12326067, 1.15072109]),
#  'LGBMRegressor': array([1.13932123, 1.11056857, 1.12900261, 1.1753656 , 1.17158268,
#         1.11182928, 1.138628  , 1.11294699, 1.13512447, 1.15299037]),
#  'RandomForestRegressor': array([1.15901123, 1.12970781, 1.14335634, 1.18273   , 1.1847961 ,
#         1.11972649, 1.14308267, 1.12176792, 1.15603761, 1.16416791]),
# ...

# %%
plt.figure(figsize=(16, 10))

for name, model in models.items():
    sns.distplot(results[name], bins=10, kde=True, label=name)

plt.title('CV Error distributions')
plt.legend()
plt.show()

# %%
# mean and std for each model
for name, result in results.items():
    print('----------\n'+ name + '\n------------')
    print(np.mean(result))
    print(np.std(result))
# Out:
# ----------
# Bayesian Ridge
# ------------
# 1.1393946115516456
# 0.027135661556790144
# ----------
# OrthogonalMatchingPursuit
# ------------
# 1.1407830606340297
# 0.028684727647371906
# ----------
# Ridge
# ------------
# 1.1463155664055256
# 0.03099659215218105
# ----------
# GradientBoostingRegressor
# ------------
# 1.1350086347015431
# 0.021455256877410362
# ----------
# LGBMRegressor
# ------------
# 1.1377359781040313
# 0.022145888157476156
# ----------
# RandomForestRegressor
# ------------
# 1.1504384078604588
# 0.021944885963053707
# ----------
# XGBRegressor
# ------------
# 1.1473787421647712
# 0.022410473793708797

# %% [markdown]
# # Combine predictions

# %%
final_predictions = (
    0.142* np.exp(models['Bayesian Ridge'].predict(test_final)) +
    0.142* np.exp(models['OrthogonalMatchingPursuit'].predict(test_final)) +
    0.142* np.exp(models['Ridge'].predict(test_final)) +
    0.142* np.exp(models['GradientBoostingRegressor'].predict(test_final)) +
    0.142* np.exp(models['LGBMRegressor'].predict(test_final)) +
    0.142* np.exp(models['RandomForestRegressor'].predict(test_final)) +
    0.142* np.exp(models['XGBRegressor'].predict(test_final)) )

# %%
final_predictions
# Out:
# array([122681.67913239, 157736.29849688, 182084.99380409, ...,
#        162183.60250139, 115797.72446724, 224953.93639319])

# %% [markdown]
# # Submission

# %%
submission = pd.concat([test_ids,pd.Series(final_predictions, name = 'SalePrice')], axis = 1)
submission
# Out:
#         Id      SalePrice
# 0     1461  122681.679132
# 1     1462  157736.298497
# 2     1463  182084.993804
# 3     1464  192361.330691
# 4     1465  192691.902200
# ...    ...            ...
# 1454  2915   81248.474914
# 1455  2916   84156.665604
# 1456  2917  162183.602501
# 1457  2918  115797.724467
# 1458  2919  224953.936393
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('./bagging ansamble(7)_submission.csv', index=False, header = True)

# %% [markdown]
# # Bagging ansamble (5)

# %%
final_predictions = (
    0.2* np.exp(models['Bayesian Ridge'].predict(test_final)) +
    0.1* np.exp(models['OrthogonalMatchingPursuit'].predict(test_final)) +
    0.1* np.exp(models['Ridge'].predict(test_final)) +
    0.3* np.exp(models['GradientBoostingRegressor'].predict(test_final)) +
    0.3* np.exp(models['LGBMRegressor'].predict(test_final)) )

# %%
final_predictions
# Out:
# array([122001.92152998, 158037.48882544, 178756.35240503, ...,
#        158481.0206348 , 118141.93356633, 225848.64277218])

# %%
submission = pd.concat([test_ids,pd.Series(final_predictions, name = 'SalePrice')], axis = 1)
submission
# Out:
#         Id      SalePrice
# 0     1461  122001.921530
# 1     1462  158037.488825
# 2     1463  178756.352405
# 3     1464  190156.369437
# 4     1465  193833.756067
# ...    ...            ...
# 1454  2915   83865.653713
# 1455  2916   80592.354014
# 1456  2917  158481.020635
# 1457  2918  118141.933566
# 1458  2919  225848.642772
#
# [1459 rows x 2 columns]

# %%
submission.to_csv('./bagging ansamble(5)+Feature_Engineering(2)+weighted_submission.csv', index=False, header = True)
